# %% [markdown]
# # ForgeBlueprint wizard
#
# Run the cell below to bring up the Jupyter version of the wizard.
# See [the docs](https://cworthy-ocean.github.io/cstar-forge/) for more information on how to use it!

# %%
from cstar.wizard.wizard import ForgeBlueprintWizardApp

app = ForgeBlueprintWizardApp()
app.display()
wiz = app.inner  # the inner ForgeBlueprintWizard; rebound if you Reload the catalog
