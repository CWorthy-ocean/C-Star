# %% [markdown]
# # C-STAR Forge — ForgeBlueprint builder
#
# Assemble a reproducible `forge_blueprint.yaml`: pick a **Model** and **Domain**, adjust
# the grid, boundaries, partitioning, and run window, review the resolved config, then
# **Download** it. Take that file to your machine of choice to run the processing step.

# %%
from cstar_forge.forge_blueprint_wizard import ForgeBlueprintWizardApp

ForgeBlueprintWizardApp().display()
